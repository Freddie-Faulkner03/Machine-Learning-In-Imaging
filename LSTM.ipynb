# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import os
import skimage.filters

from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images = []
labels = []
SIZE = 256

for directory_path in glob.glob("/content/drive/MyDrive/ML_IPData7/*"):
    label = directory_path.split("/")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
       img = cv2.imread(img_path, cv2.IMREAD_COLOR)
       img = cv2.resize(img, (SIZE, SIZE))
       images.append(img)
       labels.append(label)
# Out:
# Rifle
# Golf cart

# %%
images = np.array(images)
type(labels)
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
labelencoder = LabelEncoder()
labelencoder.fit(labels)
enc_labels = labelencoder.transform(labels)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(images, enc_labels, test_size = 0.20, random_state = 10)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(layers.Reshape((256*3, 256)))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dense(units=1))

# %%
model.compile(optimizer="adam", loss="mean_squared_error", metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 871ms/step - accuracy: 0.6779 - loss: 0.3314 - val_accuracy: 0.8844 - val_loss: 0.1280
# Epoch 2/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 861ms/step - accuracy: 0.8225 - loss: 0.1683 - val_accuracy: 0.8844 - val_loss: 0.1000
# Epoch 3/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 815ms/step - accuracy: 0.8691 - loss: 0.1133 - val_accuracy: 0.8912 - val_loss: 0.1028
# Epoch 4/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 23s 960ms/step - accuracy: 0.8689 - loss: 0.1251 - val_accuracy: 0.8912 - val_loss: 0.0964
# Epoch 5/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 825ms/step - accuracy: 0.8466 - loss: 0.1289 - val_accuracy: 0.8844 - val_loss: 0.1002
# Epoch 6/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 801ms/step - accuracy: 0.8483 - loss: 0.1315 - val_accuracy: 0.8980 - val_loss: 0.0986
# Epoch 7/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 725ms/step - accuracy: 0.8339 - loss: 0.1297 - val_accuracy: 0.8912 - val_loss: 0.0975
# Epoch 8/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 24s 970ms/step - accuracy: 0.8562 - loss: 0.1227 - val_accuracy: 0.8912 - val_loss: 0.0981
# Epoch 9/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 799ms/step - accuracy: 0.8682 - loss: 0.1101 - val_accuracy: 0.8980 - val_loss: 0.0941
# Epoch 10/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 758ms/step - accuracy: 0.8653 - loss: 0.1149 - val_accuracy: 0.8980 - val_loss: 0.0919
# Epoch 11/20

# %%
pred = model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score

y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8844
# Recall: 0.9848
# F1 Score: 0.9386
